# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d548bf55-0ca3-4471-bfd4-7a0470e15601" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d548bf55-0ca3-4471-bfd4-7a0470e15601">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import sqlite3

conn = sqlite3.connect("Chinook_Sqlite.sqlite")

# %% [markdown]
# import and connect sql file

# %%
import pandas as pd

query = """
SELECT
    Customer.LastName,
    Customer.FirstName,
    Track.Name AS TrackName,
    Album.Title AS AlbumTitle
FROM Customer
JOIN Invoice ON Customer.CustomerId = Invoice.CustomerId
JOIN InvoiceLine ON Invoice.InvoiceId = InvoiceLine.InvoiceId
JOIN Track ON InvoiceLine.TrackId = Track.TrackId
JOIN Album ON Track.AlbumId = Album.AlbumId
ORDER BY Customer.LastName, Customer.FirstName;
"""

df = pd.read_sql_query(query, conn)
df.head()
# Out:
#   LastName FirstName                                          TrackName  \
# 0  Almeida   Roberto                            Right Next Door to Hell
# 1  Almeida   Roberto                                     In The Evening
# 2  Almeida   Roberto                                   Fool In The Rain
# 3  Almeida   Roberto  Saudade Dos Aviões Da Panair (Conversando No Bar)
# 4  Almeida   Roberto                             Caso Você Queira Saber
#
#                 AlbumTitle
# 0      Use Your Illusion I
# 1  In Through The Out Door
# 2  In Through The Out Door
# 3                    Minas
# 4                    Minas

# %% [markdown]
# Query uses INNER JOIN operations to combine the Customer, Invoice, InvoiceLine, Track, and Album tables in order to relate each customer to their purchased tracks and the corresponding albums, and the results are ordered alphabetically by the customer’s last name and first name. Read the data in sql file and store in table df.
